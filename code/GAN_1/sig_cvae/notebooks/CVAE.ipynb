# %% [markdown]
# # CVAE

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_circles
from sklearn.preprocessing import MinMaxScaler

import base
import cvae
import importlib
importlib.reload(cvae)
# Out:
# <module 'cvae' from '../src/cvae.py'>

# %% [markdown]
# ## Create the data

# %%
data, conditions = make_circles(n_samples=10000, noise=0.05, factor=0.5)

# We normalise the data to [0, 1]^2
scaler = MinMaxScaler()
data = scaler.fit_transform(data)

# %%
# Plot dataset
plt.scatter(*data.T, c=conditions, s=2)
plt.show()

# %% [markdown]
# # Train the CVAE

# %%
initial_generator = cvae.CVAE(n_latent=4, alpha=0.02)

# %%
generator = cvae.CVAE(n_latent=4, alpha=0.02)
generator.train(data, data_cond=conditions.reshape(-1, 1),
                n_epochs=10000)
# Out:
# WARNING:tensorflow:From ../src/cvae.py:25: flatten (from tensorflow.python.keras.legacy_tf_layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Flatten instead.
# WARNING:tensorflow:From /home/lewis/python-environments/counterpoint/lib/python3.8/site-packages/tensorflow/python/keras/legacy_tf_layers/core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer_v1) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From ../src/cvae.py:26: dense (from tensorflow.python.keras.legacy_tf_layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# Training: 100%|██████████| 10000/10000 [06:37<00:00, 25.13it/s]

# %%
generator.__dict__
# initial_generator.__dict__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-3cd4d1287f2a> in <module>
#       1 generator.__dict__
# ----> 2 generator.save()
#       3 # initial_generator.__dict__
#
# AttributeError: 'CVAE' object has no attribute 'save'

# %% [markdown]
# # Generate samples

# %%
outer_circle_generated = generator.generate((0,), n_samples=1000)
inner_circle_generated = generator.generate((1,), n_samples=1000)

# %%
plt.scatter(*outer_circle_generated.T, s=2)
plt.scatter(*inner_circle_generated.T, s=2)
plt.show()
